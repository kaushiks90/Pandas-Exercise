# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars2.csv).

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %%
cars1=pd.read_csv("C:\Users\Karthik\Desktop\GitHub\Pandas Exercise\Data\cars1.csv")
cars2=pd.read_csv("C:\Users\Karthik\Desktop\GitHub\Pandas Exercise\Data\cars2.csv")

# %% [markdown]
# ### Step 4. Ops it seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1=cars1.iloc[:,0:9]
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars2.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  33.0          4            91         53    1795          17.4     76
# 1  20.0          6           225        100    3651          17.7     76
# 2  18.0          6           250         78    3574          21.0     76
# 3  18.5          6           250        110    3645          16.2     76
# 4  17.5          6           258         95    3193          17.8     76
#
#    origin                 car
# 0       3         honda civic
# 1       1      dodge aspen se
# 2       1   ford granada ghia
# 3       1  pontiac ventura sj
# 4       1       amc pacer d/l

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
cars1.shape
# Out:
# (198, 9)

# %%
cars2.shape
# Out:
# (200, 9)

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars3=cars1.append(cars2)
cars3
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...

# %%
cars3.shape
# Out:
# (398, 9)

# %% [markdown]
# ### Step 7. Ops there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
owners=np.random.randint(15000,73000,398,dtype='l')
owners
# Out:
# array([23939, 46390, 48014, 15462, 71712, 28247, 56555, 44823, 53857,
#        69791, 20748, 17985, 29655, 41740, 40807, 60398, 57637, 48377,
#        40441, 67624, 39152, 19328, 54223, 29213, 57849, 52695, 18852,
#        23888, 23840, 26211, 49463, 16659, 48730, 68901, 18336, 43658,
#        17863, 51052, 26212, 31963, 52462, 72436, 45037, 52611, 49099,
#        55412, 61431, 41154, 23039, 48422, 55375, 51032, 57007, 47438,
#        64003, 27501, 51135, 70302, 34523, 43665, 56122, 47272, 47595,
#        69944, 62139, 32794, 63744, 59547, 22707, 67330, 60786, 55025,
#        61555, 61372, 51233, 46985, 35594, 69747, 25170, 33094, 23320,
#        47726, 57274, 31284, 15219, 44360, 16662, 24191, 36765, 32669,
#        42318, 45984, 40799, 58143, 68259, 36021, 20059, 66794, 58119,
#        40653, 65934, 44207, 55908, 62788, 66350, 43290, 55612, 69524,
#        72995, 15714, 43402, 36487, 44962, 20808, 35775, 40034, 50183,
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars3['owners']=owners
cars3.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  owners
# 0       1  chevrolet chevelle malibu   23939
# 1       1          buick skylark 320   46390
# 2       1         plymouth satellite   48014
# 3       1              amc rebel sst   15462
# 4       1                ford torino   71712
